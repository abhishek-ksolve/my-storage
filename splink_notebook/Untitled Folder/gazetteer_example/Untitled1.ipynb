# %%
from future.builtins import next
import re
from numpy import nan
import dedupe
from unidecode import unidecode
import findspark
findspark.init()

import pyspark
from pyspark.sql import SparkSession
from pyspark.context import SparkContext
from pyspark.sql.functions import *
from pyspark.sql.session import SparkSession
import json
import pyspark.sql.functions as F
from pyspark.sql.types import IntegerType,FloatType
import warnings
warnings.simplefilter(action='ignore')

# %%
import os
import csv
import re
import logging
import optparse
import collections

# %%
spark = SparkSession \
    .builder \
    .appName("dedupe") \
    .master("local[*]") \
    .getOrCreate()

# %%
output_file = 'gazetteer_output.csv'
settings_file = 'gazetteer_learned_settings'
training_file = 'gazetteer_training.json'

# %%
primart_key="price"


# canon_file= spark.read.option("header","true").csv("data/AbtBuy_Buy.csv")
# messy_file= spark.read.option("header","true").csv("data/AbtBuy_Abt.csv")

canon_file= "data/AbtBuy_Buy.csv"
messy_file= "data/AbtBuy_Abt.csv"

# %%
def preProcess(column):
    """
    Do a little bit of data cleaning with the help of Unidecode and Regex.
    Things like casing, extra spaces, quotes and new lines can be ignored.
    """
    # column = column.decode("utf8")
    column = unidecode(column)
    column = re.sub('\n', ' ', column)
    column = re.sub('-', '', column)
    column = re.sub('/', ' ', column)
    column = re.sub("'", '', column)
    column = re.sub(",", '', column)
    column = re.sub(":", ' ', column)
    column = re.sub(' +', ' ', column)
    column = column.strip().strip('"').strip("'").lower().strip()
    if not column:
        column = None
    return column
def readData(filename):
    """
    Read in our data from a CSV file and create a dictionary of records,
    where the key is a unique record ID and each value is dict
    """
    df= spark.read.option("header","true").csv(filename)

    data_d = {}
    dfn=df.na.fill("")
    results = dfn.toJSON().map(lambda j: json.loads(j)).collect()
    for i, row in enumerate(results):
            clean_row = dict([(k, preProcess(v)) for (k, v) in row.items()])
            if clean_row['price']:
                clean_row['price'] = float(clean_row['price'][1:])
            data_d[filename + str(i)] = dict(clean_row)

    return data_d

# %%
messy = readData(messy_file)
canonical = readData(canon_file)

# %%
print('N data 2 records: {}'.format(len(canonical)))

print('N data 1 records: {}'.format(len(messy)))
# Out:
# N data 2 records: 1092
# N data 1 records: 1081

# %%
def descriptions():
        for dataset in (messy, canonical):
            for record in dataset.values():
                yield record['description']

# %%
fields = [
            {'field': 'title', 'type': 'String'},
            {'field': 'title', 'type': 'Text', 'corpus': descriptions()},
            {'field': 'description', 'type': 'Text','has missing': True, 'corpus': descriptions()},
            {'field': 'price', 'type': 'Price', 'has missing': True}]

# Create a new gazetteer object and pass our data model to it.
gazetteer = dedupe.Gazetteer(fields)

# %%
print('reading labeled examples from ', training_file)
with open(training_file) as tf:
    gazetteer.prepare_training(messy, canonical, training_file=tf)

gazetteer.train()
gazetteer.cleanup_training()

gazetteer.index(canonical)

results = gazetteer.search(messy, n_matches=2, generator=True)
# Out:
# reading labeled examples from  gazetteer_training.json

# %%
# training_file = 'gazetteer_training.json'
# with open(training_file) as tf:
#     gazetteer.prepare_training(messy, canonical, training_file=tf)

# %%
cluster_membership = {}
cluster_id = 0

for cluster_id, (messy_id, matches) in enumerate(results):
    for canon_id, score in matches:
        cluster_membership[messy_id] = {'Cluster ID': float(cluster_id),
                                        'Link Score': float(score)}
        cluster_membership[canon_id] = {'Cluster ID': float(cluster_id),
                                        'Link Score': float(score)}
        cluster_id += 1

# %%
json_cls=[]
for fileno, filename in enumerate((messy_file, canon_file)):
    df= spark.read.option("header","true").csv(filename)
    results = df.toJSON().map(lambda j: json.loads(j)).collect()
    for row_id, row in enumerate(results):
        record_id = filename + str(row_id)
        cluster_details = cluster_membership.get(record_id, {})
        print(cluster_details)
        row['source file'] = fileno
        Dict = {}
        Dict["source_file"] = row['source file']
        
        
        cluster_details.update(Dict)
        cluster_details.update(row)
        json_cls.append(cluster_details)
# Out:
# {'Cluster ID': 0.0, 'Link Score': 0.545451819896698, 'unique_id': '1', 'title': 'Linksys EtherFast 8-Port 10/100 Switch - EZXS88W', 'description': 'Linksys EtherFast 8-Port 10/100 Switch - EZXS88W/ 10/100 Dual-Speed Per-Port/ Perfect For Optimizing 10BaseT And 100BaseTX Hardware On The Same Network/ Speeds Of Up To 200Mbps In Full Duplex Operation/ Eliminate Bandwidth Constraints And Clear Up Bottlenecks', 'price': '$44.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 1.0, 'Link Score': 0.5454487800598145, 'unique_id': '2', 'title': 'Linksys EtherFast10/100 5-Port Auto-Sensing Switch - EZXS55W', 'description': 'Linksys EtherFast10/100 5-Port Auto-Sensing Switch - EZXS55W/ 5 Port 10/100 Autosensing Ports With Both Half And Full Duplex Modes/ Perfect For Integrating Your 10BaseT And 100BaseTX Network Hardware/ Switched 10/100 Ports Run At 10Mbps, 20Mbps, 100Mbps Up To 200Mbps', 'price': '$29.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 126.0, 'Link Score': 0.5454509854316711, 'unique_id': '3', 'title': 'Netgear ProSafe 5 Port 10/100 Desktop Switch - FS105', 'description': 'Netgear ProSafe 5 Port 10/100 Desktop Switch - FS105/ 5 Auto Speed-Sensing 10/100 UTP Ports/ Embedded Memory', 'price': '$40.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 200.0, 'Link Score': 0.5454516410827637, 'unique_id': '4', 'title': 'Belkin F3H982-10 Pro Series High Integrity 10 Feet Monitor Cable - F3H98210', 'description': "Belkin F3H982-10 Pro Series High Integrity 10 Feet Monitor Cable - F3H98210/ Recommended For Monitors 17' And Larger/ Designed To Support High Resolution Imaging And High Speed/ Double Shielding/ Gold Plated Copper Contacts", 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 356.0, 'Link Score': 0.5454540252685547, 'unique_id': '6', 'title': 'LaCie USB 2.0 Floppy Disk Drive - 706018', 'description': 'LaCie USB 2.0 Floppy Disk Drive - 706018/ Ultra-Thin Portable Design/ Compatible With Windows And Mac OS/ Plug And Play/ USB Powered/ 250 - 500 kbps Transfer Rate/ Silver Finish', 'price': '$49.00', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 504.0, 'Link Score': 0.5454544425010681, 'unique_id': '8', 'title': 'Kensington Orbit Optical Trackball Mouse - 64327', 'description': 'Kensington Orbit Optical Trackball Mouse - 64327/ DiamondEye Optical Technology For Precise Tracking And Cursor Control/ USB And PS/2 Connectivity For Greater Compatibility/ Windows And Mac Compatible/ Metallic Silver And Black Finish', 'price': '$38.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 573.0, 'Link Score': 0.545451819896698, 'unique_id': '9', 'title': 'Linksys EtherFast4116 16-Port 10/100 Ethernet Switch - EF4116', 'description': 'Linksys EtherFast4116 16-Port 10/100 Ethernet Switch - EF4116/ 16 Autosensing 10/100 Full Duplex Auto MDI/MDI-X Ports/ Run Blazing Speeds Up To 200Mbps/ Address Learning And Aging And Data Flow Control', 'price': '$79.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 651.0, 'Link Score': 0.5454521775245667, 'unique_id': '10', 'title': 'Linksys EtherFast 4124 24-Port Ethernet Switch - EF4124', 'description': 'Linksys EtherFast 4124 24-Port Ethernet Switch - EF4124/ 24 Autosensing 10/100 Full Duplex, Auto MDI/MDI-X Ports/ Up To 200Mbps/ Address Learning, Aging And Data Flow Control/ Compact Size', 'price': '$119.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 2.0, 'Link Score': 0.5454468131065369, 'unique_id': '11', 'title': 'Linksys Gigabit 5-Port Workgroup Switch - EG005W', 'description': 'Linksys Gigabit 5-Port Workgroup Switch - EG005W/ Five 10/100/1000Mbps, Half/Full Duplex, Switched Ports/ Forwards And Filters Packets At Non-Blocking, Full Wire Speed/ All Ports Have Auto Speed Negotiation And Auto MDI/MDI-X Crossover Detection/ Supports Address Learning And Aging, 802.3x Flow Control And Head-Of-Line Blocking Prevention', 'price': '$64.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 55.0, 'Link Score': 0.545448899269104, 'unique_id': '12', 'title': 'Linksys Wireless-G Ethernet Bridge - WET54G', 'description': 'Linksys Wireless-G Ethernet Bridge - WET54G/ Converts Wired-Ethernet Devices To Wireless-G Network Connectivity/ For Windows, Macintosh, Linux, PlayStation Consoles, Xbox Consoles, Or Anything With An Ethernet Port/ Plug And Play, No Driver Installation Require', 'price': '$89.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 63.0, 'Link Score': 0.5454554557800293, 'unique_id': '13', 'title': 'Tripp-Lite PV375 PowerVerter 375-Watt Ultra-Compact Inverter - PV375', 'description': 'Tripp-Lite PV375 PowerVerter 375-Watt Ultra-Compact Inverter - PV375/ 12V DC Input/ 120V AC Output/ 2 Outlets/ 375 Watts Continuous Output/ 600 Watts Peak Output/ Convenient Cigarette Lighter Plug', 'price': '$49.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 71.0, 'Link Score': 0.5454522371292114, 'unique_id': '14', 'title': 'Netgear Prosafe 5 Port Gigabit Ethernet Desktop Switch - GS105NA', 'description': 'Netgear Prosafe 5 Port Gigabit Ethernet Desktop Switch - GS105NA/ Auto-Switching Ethernet Connection/ Supports Windows And Macintosh Platforms/ Dual Color LEDs/ AutoUplink Technology/ Compact Metal Case/ Fanless Design/ Plug-And-Play Installation', 'price': '$55.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 79.0, 'Link Score': 0.5454515218734741, 'unique_id': '15', 'title': 'Belkin F3H982-25 Black 25 Ft Pro Series High Integrity VGA/SVGA Monitor Replacement Cable - F3H98225', 'description': 'Belkin F3H982-25 Black 25 Ft Pro Series High Integrity VGA/SVGA Monitor Replacement Cable - F3H98225/ Constructed Of 3 Coaxial And 5 Twisted Pair Cable/ Compatible With The PC/ Aluminum Undermold Shield/ Double Shielding/ Gold Plated Copper Contacts', 'source_file': 0, 'source file': 0}
# {'Cluster ID':
00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 161.0, 'Link Score': 0.5454527139663696, 'unique_id': '26', 'title': 'Netgear RangeMax Wireless Access Point - White Finish - WPN802NA', 'description': 'Netgear RangeMax Wireless Access Point - WPN802NA/ Improves Performance Of Existing Legacy 802.11b And 802.11g Wireless Devices Up To 50 Percent/ Wired Equivalent Privacy (WEP) 64-Bit,128-Bit Encryption/ Wi-Fi Protected Access (WPA, Pre-Shared Key)', 'price': '$130.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 170.0, 'Link Score': 0.5454533100128174, 'unique_id': '27', 'title': 'NetGear ProSafe 24 Port Smart Switch - FS726TP', 'description': 'NetGear ProSafe 24 Port Smart Switch - FS726TP/ Two Gigabit Ports Plus Easy Browser/ ProSafe Network Management Software/ Web Based Smart Management Features', 'price': '$605.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 176.0, 'Link Score': 0.5454526543617249, 'unique_id': '28', 'title': 'Sony PlayStation 2 8MB Memory Card - Black Finish - 711719702702', 'description': 'Sony PlayStation 2 8MB Memory Card - 711719702702/ Save And Load High Scores, Positions And Replays/ MagicGate Encryption/ Black Finish', 'price': '$24.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 185.0, 'Link Score': 0.5454524755477905, 'unique_id': '29', 'title': 'Sony PlayStation 2 8MB Memory Card (2 Pack) - Red/Blue Finish - 711719706700', 'description': 'Sony PlayStation 2 8MB Memory Card (2 Pack) - 711719706700/ Save And Load High Scores, Positions And Replays/ MagicGate Encryption/ Red/Blue Finish', 'price': '$34.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 193.0, 'Link Score': 0.5454540252685547, 'unique_id': '30', 'title': 'Sony PlayStation 2 DUALSHOCK 2 Analog Controller - Emerald Finish - 711719706205', 'description': 'Sony PlayStation 2 DUALSHOCK 2 Analog Controller - 711719706205/ Analog Pressure Sensitivity On All Action Buttons/ Built-In DUALSHOCK Vibration Function/ Twin Analog Control Sticks/ Intelligent Self-Calibrating Analog System/ Emerald Finish', 'price': '$24.99', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 208.0, 'Link Score': 0.5454477667808533, 'unique_id': '32', 'title': 'Sennheiser Rechargeable Nickel-Metal Hydride Battery - BA151', 'description': 'Sennheiser Rechargeable Nickel-Metal Hydride Battery - BA151/ Rechargeable Battery For Wireless Sennheiser Headphones', 'price': '$20.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 213.0, 'Link Score': 0.5454497933387756, 'unique_id': '33', 'title': 'Sony MiniDV Cleaning Cassette - DVM12CLD', 'description': 'Sony MiniDV Cleaning Cassette - DVM12CLD/ Play For 10 Seconds And It Cleans The Heads Of Your MiniDV Camcorder For Picture-Perfect Performance/ Designed For all MiniDV Camcorders And MiniDV VCRs', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 220.0, 'Link Score': 0.545448899269104, 'unique_id': '34', 'title': 'Sony Switcher - SBV40S', 'description': 'Sony Switcher - SBV40S/ Eliminates Disconnecting And Reconnecting Cables/ Compact Design/ 4 A/V Inputs With S-Video Jacks/ 1 A/V Output With S-Video (Y/C)Jack/ 2 Audio Output', 'price': '$49.00', 'source_file': 0, 'source file': 0}
# {}
# {}
# {}
# {}
# {'Cluster ID': 256.0, 'Link Score': 0.5454517006874084, 'unique_id': '39', 'title': 'Belkin Pro Series 16 Ft.  USB 2.0 Cable - F3U13316', 'description': 'Belkin Pro Series 16 Ft. USB 2.0 Device Cable - F3U13316/ Hi-Speed Data Transfer To 480Mbps/ Impedance Matched Twisted Pair Construction/ Gold Plated Copper Contacts/ 16 Feet', 'source_file': 0, 'source file': 0}
# {}
# {}
# {}
# {}
# {}
# {'Cluster ID': 299.0, 'Link Score': 0.5454487800598145, 'unique_id': '45', 'title': 'Panasonic Hands-Free Headset - KXTCA86', 'description': 'Panasonic Hands-Free Headset - KXTCA86/ Comfort Fit And  Fold Design/ Noise Cancelling Microphone/ Standard 2.5mm Connection', 'price': '$14.95', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 307.0, 'Link Score': 0.5454504489898682, 'unique_id': '46', 'title': 'Sony Lightweight Tripod - Black Finish - VCTR640', 'description': 'Sony Lightweight Tripod - VCTR640/ Adjustable Height And Three-Way Head Allow For Creative Camera Angles/ Quick-Release Head Allows You To Remove Your Camera Quickly And Easily/ Black Finish', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 319.0, 'Link Score': 0.5454516410827637, 'unique_id': '47', 'title': "Sanus 13' - 30' VisionMount Flat Panel TV Silver Wall Mount - VMFS", 'description': "Sanus 13' - 30' VisionMount Flat Panel TV Silver Wall Mount - VMFS/ Supports Up To 40 lbs/ Easy To Install/ Fingertip Virtual Axis Tilting System/ Silver Finish", 'price': '$39.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 325.0, 'Link Score': 0.545449435710907, 'unique_id': '48', 'title': 'Sanus WMS3B Black Weather Resistant Small Speaker Wall Mount - WMS3B', 'description': 'Sanus WMS3B Black Small Speaker Wall Mount - WMS3B/ Holds Up To An 8 Pound Speaker/ Multiple Pivot Points/ Weather Resistant For Indoor/Outdoor Use/ Black Finish/ Priced Per Pair', 'price': '$29.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 336.0, 'Link Score': 0.5454479455947876, 'unique_id': '49', 'title': 'Sanus WMS3S Silver Weather Resistant Small Speaker Wall Mount - WMS3S', 'description': 'Sanus WMS3S Silver Small Speaker Wall Mount - WMS3S/ Holds Up To An 8 Pound Speaker/ Multiple Pivot Points/ Weather Resistant For Indoor/Outdoor Use/ Silver Finish/ Priced Per Pair', 'price': '$29.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 346.0, 'Link Score': 0.5454457998275757, 'unique_id': '50', 'title': 'Sony DVD-R Recordable Camcorder Media - 3DMR30L1H', 'description': 'Sony DVD-R Recordable Camcorder Media 3 Pack - 3DMR30L1H/ 30 Minute, 1.4 GB/ Accucore Technology/ Store Digital Video, Audio And Multimedia Files/ 3 Pack', 'price': '$9.99', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 365.0, 'Link Score': 0.5454495549201965, 'unique_id': '51', 'title': 'Panasonic Corded Phone - KXTS3282B', 'description': 'Panasonic Corded Phone - KXTS3282B/ 2 Phone Lines/ Call Waiting/ 50-Station Caller ID/ Speakerphone/ 3-Line LCD Display/ Black Finish', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 369.0, 'Link Score': 0.5454517602920532, 'unique_id': '52', 'title': 'Sennheisser Hi-Fi Wireless Headphone - RS120', 'description': 'Sennheisser Hi-Fi Wireless Headphone - RS120/ Supra Aural/ Wireless RF Headphone System/ Range Of Up To 100 Meters/ Three Selectable RF Channels/ Transmitter With Metal Cradle', 'source_file': 0, 'source file': 0}
# {'Cluster ID':
00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 696.0, 'Link Score': 0.5454461574554443, 'unique_id': '97', 'title': 'Canon High Capacity Color Ink Cartridge - Color Ink - CL51', 'description': 'Canon High Capacity Color Ink Cartridge - CL51/ Compatible With Pixma iP6210D, iP6220D, MP150, MP170 And MP450 Printers', 'price': '$35.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 700.0, 'Link Score': 0.5454540848731995, 'unique_id': '98', 'title': 'Canon Black Ink Cartridge - PG50', 'description': 'Canon Black Ink Cartridge - PG50/ Pigment Ink Formulation For Long Lasting Prints/ Resists Smearing Caused By Highlighters/ Smudge Resistant/ Ink Remaining Notification Technology/ Crisp Laser Text-Quality Text/ Black Ink', 'price': '$29.00', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 3.0, 'Link Score': 0.5454493165016174, 'unique_id': '100', 'title': 'Delonghi Twenty Four Seven Coffee Maker In Black - DC50B', 'description': 'Delonghi Twenty Four Seven Coffee Maker - DC50B/ 4-Cup Capacity/ Easy-Access, Washable Filter Basket/ Black Finish', 'price': '$22.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 11.0, 'Link Score': 0.5454481840133667, 'unique_id': '101', 'title': 'Panasonic LM-AF30U3 Three Pack Of Single-Sided 30 Minute DVD-RAM Discs - LMAF30U3', 'description': 'Panasonic LM-AF30U3 Three Pack Of Single-Sided 30 Minute DVD-RAM Discs - LMAF30U3/ Compatible With DVD Camcorder, DVD Video Recorders And DVD-RAM Drives/ Rewritable/ XTRA, Fine And Standard Recording Modes/ 1.4 GB Data Capacity', 'price': '$8.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 17.0, 'Link Score': 0.5454581379890442, 'unique_id': '102', 'title': 'Belkin Hi-Speed USB 2.0 7-Port Hub - F5U237APLS', 'description': 'Belkin Hi-Speed USB 2.0 7-Port Hub - F5U237APLS/ Transfers Data Up To 480Mbps/ Installs Easily With Plug-And-Play Convenience/ Works Seamlessly With All USB 1.1 And USB 2.0 Devices/ Over-Current Detection And Safety/ Mac And PC Compatible/ Silver Finish', 'price': '$49.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 21.0, 'Link Score': 0.5454565286636353, 'unique_id': '103', 'title': 'Canon Black EF 70-300mm F/4-5.6 IS USM Telephoto Zoom Lens - 0345B002', 'description': 'Canon Black EF 70-300mm F/4-5.6 IS USM Telephoto Zoom Lens - 0345B002/ 15 Elements In 10 Groups Lens Construction/ 4.9 Feet Closest Focusing Distance/ 6-Group Helical Zoom/ 58MM Filter Size/ Black Finish', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 30.0, 'Link Score': 0.5454508662223816, 'unique_id': '104', 'title': 'Universal IR/RF Aeros Remote Control- MX850 - MX850', 'description': 'Universal IR/RF Aeros Remote Control- MX850/ Laser Etched Buttons/ Centrally Located Joystick/ Memory Back-Up/ One Hand Ergonomics/ Controls Up To 20 Components', 'price': '$399.95', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 36.0, 'Link Score': 0.5454505085945129, 'unique_id': '105', 'title': 'Universal IR/RF Remote - MX350', 'description': 'Universal IR/RF Remote - MX350/ Controls Up To 10 Components/ Extensive Macro Programming/ Memory Back-Up/ One Hand Ergonomics', 'price': '$149.95', 'source_file': 0, 'source file': 0}
# {}
# {}
# {'Cluster ID': 53.0, 'Link Score': 0.5454503297805786, 'unique_id': '108', 'title': 'Linksys Wireless-G Broadband Router - WRT54GL', 'description': 'Linksys Wireless-G Broadband Router - WRT54GL/ All-In-One Internet-Sharing Router/ 4-Port Switch/ Push Button Setup Feature/ TKIP And AES Encryption/ Wireless MAC Address Filtering/ Powerful SPI Firewall/ 54Mbps Wireless-G (802.11g) Access Point', 'price': '$79.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 54.0, 'Link Score': 0.5454500913619995, 'unique_id': '109', 'title': 'Terk XM Outdoor Home Antenna - Grey Finish - XM6', 'description': 'Terk XM Outdoor Home Antenna - XM6/ Universal Mounting Roof, Wall Or Mast/ For Use With Single-Input Receivers/ Connects RG6 Cable For Easy Routing Up To 100 Ft. (Optimal Disatnce 75 Ft.)', 'price': '$80.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 56.0, 'Link Score': 0.5454477071762085, 'unique_id': '110', 'title': 'Nikon AF Speedlight Accessory - SB600', 'description': 'Nikon AF Speedlight Accessory - SB600/ Versatile Remote Speedlight/ i-TTL Flash Control/ FV Lock (Flash Value Lock)/ Auto FP High Speed Sync Mode', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 57.0, 'Link Score': 0.545455813407898, 'unique_id': '111', 'title': 'Sony Memory Stick Duo Replacement Adaptor - Silver/Blue Finish - MSACM2', 'description': 'Sony Memory Stick Duo Replacement Adaptor - MSACM2/ Compatible With Memory Stick Duo And Pro Media Stick/ Compact, Thin, And Extremely Lightweight', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 58.0, 'Link Score': 0.5454556345939636, 'unique_id': '112', 'title': 'Kensington MicroSaver Keyed Notebook Lock - 64068F', 'description': 'Kensington MicroSaver Keyed Notebook Lock - 64068F/ Steel Composite Cable With Carbon Tempered Steel Core/ Built-In Defense System/ T-Bar Lock/ Easy To Install', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 59.0, 'Link Score': 0.5454480051994324, 'unique_id': '113', 'title': 'Linksys Compact Wireless-G USB Adapter - WUSB54GC', 'description': 'Linksys Compact Wireless-G USB Adapter - WUSB54GC/ Connects Your Desktop Or Notebook To A Wireless Network At Up To 54Mbps When Used With A USB 2.0 Port/ Compatible With Wireless-B Networks (At 11Mbps)/ Protected By WPA and Up To 128-Bit Data Encryption', 'price': '$39.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 60.0, 'Link Score': 0.5454532504081726, 'unique_id': '114', 'title': 'Sirius External Home Antenna - 14240', 'description': 'Sirius External Home Antenna - 14240/ Adjustable Design/ Durable UV-Coated Weather Resistant Construction/ Included Is A 30 Cable And Complete Mounting Hardware/ Compatible With Single Input SIRIUS Home Tuners And Plug & Play Receivers', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 61.0, 'Link Score': 0.5454496145248413, 'unique_id': '116', 'title': 'Audiovox Xpress XM Satellite Radio Receiver Home Kit - XMH10A', 'description': 'Audiovox Xpress XM Satellite Radio Receiver Home Kit - XMH10A/ Table Top Docking Station/ AC/DC Power Adapter/ RCA Audio Cables/ Weather Resistant Window Sill Antenna', 'source_file': 0, 'source file': 0}
# {}
# {}
# {'Cluster ID': 62.0, 'Link Score': 0.5454521179199219, 'unique_id': '119', 'title': 'Sony Memory Stick USB Adaptor - MSACUS40', 'description': 'Sony Memory Stick USB Adaptor - MSACUS40/ Quickly Transfer Image And Data To A PC/ Transfer Speed Up To 80Mbps/ Compatible With All Memory Stick Media', 'price': '$29.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID':
finish', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 83.0, 'Link Score': 0.5454527735710144, 'unique_id': '144', 'title': 'Pioneer Wired Marine Remote Control Display - CDMR80D', 'description': 'Pioneer Wired Marine Remote Control Display - CDMR80D/ Compatible With Pioneer Headunits/ Satellite Radio Text Indications/ ATT (Volume Attenuator) Button', 'price': '$149.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 84.0, 'Link Score': 0.5454513430595398, 'unique_id': '145', 'title': 'Pioneer XM Digital Satellite Tuner for Pioneer Headunits - GEXP920XM', 'description': 'Pioneer XM Digital Satellite Tuner For Pioneer Headunits - GEXP920XM/ SAT Radio Ready/ XM Ready/ Built-In FM Modulator/ 18- Station/ 6- Button Presets/ Magne Mount Installation', 'price': '$98.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 85.0, 'Link Score': 0.5454504489898682, 'unique_id': '146', 'title': "Pioneer 4'x6' 2-Way Component Plate Speaker - TSP462", 'description': "Pioneer 4'x6' 2-Way Component Plate Speaker - TSP462/ 150 Watts Maximum Power/ Foamed IMPP Composite Cone/ 1' Soft Dome Tweeter", 'source_file': 0, 'source file': 0}
# {}
# {}
# {'Cluster ID': 86.0, 'Link Score': 0.5454527735710144, 'unique_id': '148', 'title': 'Canon NB-5L Lithium Battery - 1135B001', 'description': 'Canon NB-5L Lithium Battery - 1135B001/ Compatible With Canon PowerShot SD700 And Ixus 800 Digital Cameras', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 88.0, 'Link Score': 0.5454524159431458, 'unique_id': '150', 'title': 'Bose Acoustimass 5 Series III Speaker System - AM53BK', 'description': "Bose Acoustimass 5 Series III Speaker System - AM53BK/ 2 Dual Cube Speakers With Two 2-1/2' Wide-range Drivers In Each Speaker/ Powerful Bass Module With Two 5-1/2' Woofers/ 200 Watts Max Power/ Black Finish", 'price': '$399.00', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 89.0, 'Link Score': 0.5454487800598145, 'unique_id': '152', 'title': 'Apple Mini-DVI To DVI Adapter - M9321GB', 'description': "Apple Mini-DVI To DVI Adapter - M9321GB/ Compatible With iMac (Intel Core Duo), MacBook And 12' PowerBook G4/ Connects To An External DVI Monitor Or Projector/ White Finish", 'price': '$19.00', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 91.0, 'Link Score': 0.5454522371292114, 'unique_id': '154', 'title': "Sanus 15' - 40' VisionMount Flat Panel TV Black Wall Mount - MF110B", 'description': "Sanus 15' - 40' VisionMount Flat Panel TV Black Wall Mount - MF110B/ Mounts Within 2.5' Of Wall/ Holds Up To 100 Lbs/ Powder Coated Black Finish", 'price': '$179.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 91.0, 'Link Score': 0.5454521179199219, 'unique_id': '155', 'title': "Sanus 15' To 40' Flat Panel Black TV Wall Mount - ML22B1", 'description': "Sanus 15' To 40' Flat Panel Black TV Wall Mount - ML22B1/ Solid Heavy-Gauge Steel Construction/ Durable Powder-Coated Finish/ Fits Most Medium Flat Panel LCD TVs Up To 100 Lbs/ Black Finish", 'source_file': 0, 'source file': 0}
# {'Cluster ID': 93.0, 'Link Score': 0.5454525947570801, 'unique_id': '156', 'title': "Sanus 15' - 40' VisionMount Flat Panel TV Black Wall Mount - MT25B1", 'description': "Sanus 15' - 40' VisionMount Flat Panel TV Black Wall Mount - MT25B1/ Solid Heavy-Gauge Steel Construction/ Durable Powder-Coated Finish/ Virtual Axis Tilt Adjustment System/ Up to 100 Lbs Support/ Black Finish", 'price': '$99.99', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 93.0, 'Link Score': 0.5454515218734741, 'unique_id': '157', 'title': 'Panasonic Yeast Pro Automatic Breadmaker - SDYD250', 'description': 'Panasonic Yeast Pro Automatic Breadmaker - SDYD250/ Patented Yeast Dispenser/ 2.5 lb To 1.5 lb Loaf/ Choice Of Bread And Baking Modes/ 13 Hour Countdown Digital Timer/ Nonstick Coating For Easy Cleanup', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 94.0, 'Link Score': 0.5454532504081726, 'unique_id': '158', 'title': 'Canon Black Leather Camera Case - 1588B001', 'description': 'Canon Black Leather Camera Case - 1588B001/ Compatible With Canon Digital ELPH Cameras/ Protects Your Camera From Dust And Scratches/ Wrist Strap For Easy Portability/ Black Finish', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 96.0, 'Link Score': 0.5454511046409607, 'unique_id': '159', 'title': 'Garmin 010-10702-00 Black GA 25MCX Remote GPS Antenna - 0101070200', 'description': 'Garmin 010-10702-00 Black GA 25MCX Remote GPS Antenna - 0101070200/ Built-In Magnetic Mount/ Includes A Cable Over 8 Feet Long And MCX Connector', 'price': '$30.00', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 97.0, 'Link Score': 0.5454486012458801, 'unique_id': '160', 'title': 'Garmin 010-10723-00 AC Adapter Cable With International Adapters - 0101072300', 'description': 'Garmin 010-10723-00 AC Adapter Cable With International Adapters - 0101072300/ Includes UK & Euro Adapters/ Black Finish', 'source_file': 0, 'source file': 0}
# {'Cluster ID': 98.0, 'Link Score': 0.5454527139663696, 'unique_id': '161', 'title': 'Garmin Replacement USB Cable - 0101072301', 'description': 'Garmin Replacement USB Cable - 0101072301/ Link PC To The Car GPS System/ Transfer And Download Created Routes, Maps From PC To GPS/ Black Finish', 'source_file': 0, 'source file': 0}
# {}
# {'Cluster ID': 100.0, 'Link Score': 0.5454477667808533, 'unique_id': '163', 'title': 'Garmin 010-10723-03 Nuvi Suction Cup Mount - 0101072303', 'description': 'Garmin 010-10723-03 Nuvi Suction Cup Mount - 0101072303/ Replacement Suction Cup Mount/ Compatible With Garmin Nuvi 300/310/350/360 GPS System/ Black Finish', 'price': '$39.00', 'source_file': 0, 'source file': 0}
# {}
# {}
# {'Cluster ID': 100.0, 'Link Score': 0.5454505085945129, 'unique_id': '166', 'title': 'Sharp Over The Counter Microwave Oven - R1214SS', 'description': 'Sharp Over The Counter Microwave Oven - R1214SS/ 1.5 Cubic Foot Capacity/ 1100 Watts/ 24 Automatic Settings/ 2-Color Lighted LCD/ Smart And Easy Sensor Settings/ Auto-Touch Control Panel/ Stainless Steel Finish', 'price': '$429.00', 'source_file': 0, 'source file': 0}
# ...
# {'Cluster ID': 682.0, 'Link Score': 0.5454502105712891, 'unique_id': '951', 'title': 'Canon CLI-221 Yellow Ink Cartridge - 2949B001', 'description': 'Yellow', 'price': '$11.99', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 683.0, 'Link Score': 0.5454508662223816, 'unique_id': '952', 'title': 'Nikon D90 Digital SLR Camera with AF-S DX Nikkor 18-105mm f/3.5-5.6G ED VR Lens - 25448', 'description': "Nikon D90 12 Megapixel Digital SLR Camera w/ 3' LCD, Live View, 18-105mm Lens, 4.5 fps Burst & In-Camera Image Editing", 'price': '$1,159.88', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 684.0, 'Link Score': 0.545449435710907, 'unique_id': '954', 'title': 'Canon PIXMA iP4600 Inkjet Color Photo Printer - 2909B002', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 685.0, 'Link Score': 0.5454502105712891, 'unique_id': '955', 'title': 'Sony VAIO JS All-in-One Desktop - VGCJS130J/B', 'description': 'Sony VAIO VGC-JS130J/B Desktop 20.1-Inch All-in-one PC -2.5 GHz Intel Pentium Dual-Core E5200 Processor, 4 GB RAM, 500 GB Hard Drive, Vista Premium - Black', 'price': '$1,028.53', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 687.0, 'Link Score': 0.5454503297805786, 'unique_id': '957', 'title': "Samsung 9 Series LN55A950 55' LCD TV", 'description': "55' - ATSC, NTSC - 181 Channels - 16:9 - 1920 x 1080 - Surround - HDTV - 1080p", 'price': '$4,049.98', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 688.0, 'Link Score': 0.5454487800598145, 'unique_id': '958', 'title': 'TiVo TCD658000 - HD XL Digital Video Recorder', 'price': '$544.07', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 689.0, 'Link Score': 0.5454520583152771, 'unique_id': '959', 'title': 'Canon PIXMA MP620 Wireless Photo All-In-One Inkjet Printer - 2921B002', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 690.0, 'Link Score': 0.5454505681991577, 'unique_id': '960', 'title': 'Canon PIXMA MP980 Wireless All-in-One Color Photo Inkjet Printer - 2922B002', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 691.0, 'Link Score': 0.5454544425010681, 'unique_id': '961', 'title': 'Sony VAIO RT All-in-One Desktop - VGCRT150Y', 'description': "Sony VAIO RT150Y All In One Desktop Computer 2.66Ghz Intel Core 2 Quad 9400 Processor, 8GB RAM, 1TB Hard Drive, BD-RE Drive, NVIDIA GeForce 9600M GT, 25.5' WUXGA HD Display, Windows Vista Ultimate", 'source_file': 1, 'source file': 1}
# {'Cluster ID': 692.0, 'Link Score': 0.5454514622688293, 'unique_id': '962', 'title': 'Sony VAIO LV All-in-One Desktop - VGCLV150J', 'description': 'Sony VAIO VGC-LV150J Desktop 24-Inch All-in-One PC - 2.53 GHz Intel Core 2 Duo E7200 Processor, 4 GB RAM, 500 GB Hard Drive, Blu-ray Drive, Windows Vista Home Premium- Silver', 'price': '$1,954.27', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 693.0, 'Link Score': 0.5454505681991577, 'unique_id': '964', 'title': 'Canon VIXIA HG20 High Definition Camcorder - 3085B001AA', 'price': '$557.64', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 694.0, 'Link Score': 0.5454503893852234, 'unique_id': '965', 'title': 'Canon VIXIA HG21 High Definition Camcorder - 2704B001AA', 'price': '$798.97', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 696.0, 'Link Score': 0.545449435710907, 'unique_id': '966', 'title': 'Canon DC310 Digital Camcorder - 2694B001', 'description': 'Canon DC310 DVD Camcorder w/ 41x Advanced Zoom, Built-in Lens Cover, Image Stabilization, & Canon Exclusive- DIGIC DV II', 'price': '$289.95', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 697.0, 'Link Score': 0.5454460978507996, 'unique_id': '967', 'title': 'Sony ICF-S79W Weather Band Digital Shower Radio - ICFS79W', 'price': '$42.00', 'source_file': 1, 'source file': 1}
# {}
# {}
# {}
# {}
# {'Cluster ID': 698.0, 'Link Score': 0.5454481244087219, 'unique_id': '972', 'title': '4G Nano ToughSkin - Black - NN4-TS-BLK', 'price': '$18.58', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 699.0, 'Link Score': 0.5454502701759338, 'unique_id': '974', 'title': "Samsung 9 Series LN46A950 46' LCD TV", 'description': "46' - ATSC, NTSC - 181 Channels - 16:9 - 1920 x 1080 - Surround - HDTV - 1080p", 'price': '$2,699.98', 'source_file': 1, 'source file': 1}
# {}
# {}
# {}
# {'Cluster ID': 701.0, 'Link Score': 0.5454494953155518, 'unique_id': '978', 'title': 'Canon PowerShot SD880 IS Digital Camera - Silver - 3197B001', 'description': "Canon PowerShot SD880 IS 10 Megapixel Digital Camera w/ UA Lens, 4x Optical Zoom, 28mm Wide Lens, Optical Image Stabilizer, & PureColor II 3' LCD - Silver", 'price': '$246.88', 'source_file': 1, 'source file': 1}
# {}
# {}
# {}
# {}
# {'Cluster ID': 702.0, 'Link Score': 0.5454506278038025, 'unique_id': '983', 'title': 'Belkin Folio for iPod touch - F8Z373', 'description': 'Leather - Black', 'price': '$19.99', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 703.0, 'Link Score': 0.5454475283622742, 'unique_id': '984', 'title': 'Griffin 8245-IP2MGNFI Clarifi Protective case for Smartphone', 'description': 'Polycarbonate - Black', 'price': '$18.99', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 704.0, 'Link Score': 0.5454499125480652, 'unique_id': '987', 'title': 'AppleCare for iPod touch or iPod classic - MB591LL/A', 'price': '$49.99', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 705.0, 'Link Score': 0.5454473495483398, 'unique_id': '990', 'title': 'Apple 8GB iPod nano Silver (4th Generation) - MB598LL/A', 'price': '$146.75', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 709.0, 'Link Score': 0.5454450249671936, 'unique_id': '991', 'title': 'Apple 8GB iPod nano Blue (4th Generation) - MB732LL/A', 'price': '$146.75', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 710.0, 'Link Score': 0.5454450845718384, 'unique_id': '992', 'title': 'Apple 8GB iPod nano Pink (4th Generation) - MB735LL/A', 'price': '$146.75', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 708.0, 'Link Score': 0.545447587966919, 'unique_id': '993', 'title': 'Apple 8GB iPod nano Purple (4th Generation) - MB739LL/A', 'price': '$146.75', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 709.0, 'Link Score': 0.5454473495483398, 'unique_id': '994', 'title': 'Apple 8GB iPod nano Green (4th Generation) - MB745LL/A', 'price': '$139.88', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 4.0, 'Link Score': 0.5454471707344055, 'unique_id': '996', 'title': 'Apple 8GB iPod nano Black (4th Generation) - MB754LL/A', 'price': '$146.75', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 6.0, 'Link Score': 0.5454496741294861, 'unique_id': '999', 'title': 'USB POWER ADAPTER ACCS - MB352LL/B', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 7.0, 'Link Score': 0.545455276966095, 'unique_id': '1000', 'title': 'Belkin Switch-to-Mac Cable - F4U001', 'description': '1 x USB - 1 x USB - 8ft - White', 'price': '$21.80', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 8.0, 'Link Score': 0.5454429984092712, 'unique_id': '1001', 'title': 'Apple iPod touch 8GB Flash Portable Media Player - MB528LLA', 'description': "Audio Player, Video Player, Photo Viewer - 3.5' Color LCD - 8GB Flash Memory", 'price': '$229.00', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 9.0, 'Link Score': 0.5454432368278503, 'unique_id': '1002', 'title': 'Apple iPod touch 16GB Flash Portable Media Player - MB531LLA', 'description': "Audio Player, Video Player, Photo Viewer - 3.5' Color LCD - 16GB Flash Memory", 'price': '$309.99', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 10.0, 'Link Score': 0.5454465746879578, 'unique_id': '1005', 'title': "Coby Electronics TF-TV1514 15' LCD TV", 'description': "15' - Active Matrix TFT - ATSC, NTSC - 16:9 - 1280 x 800 - HDTV", 'price': '$149.99', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 12.0, 'Link Score': 0.5454525947570801, 'unique_id': '1008', 'title': 'Sony DPFD80 Digital Photo Frame', 'description': "Photo Viewer - 8' LCD", 'source_file': 1, 'source file': 1}
# {'Cluster ID': 13.0, 'Link Score': 0.5454525947570801, 'unique_id': '1009', 'title': 'Transcend 2.5 Solid State Disk (SSD) 128GB SATA MLC with Build-In ECC - TS128GSSD25S-M', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 14.0, 'Link Score': 0.5454477667808533, 'unique_id': '1010', 'title': 'VholdR 2200 Mount Adhesive (Black)', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 15.0, 'Link Score': 0.5454471111297607, 'unique_id': '1013', 'title': 'MOTOROLA T305 BLUETOOTH VISOR SPEAKER PHONE CAR KIT - RETAIL - 89082J', 'price': '$46.93', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 16.0, 'Link Score': 0.5454499125480652, 'unique_id': '1014', 'title': 'Aliph Jawbone 2 Silver Bluetooth Headset - Retail - 84442VRP', 'price': '$89.99', 'source_file': 1, 'source file': 1}
# {}
# {}
# {}
# {}
# {'Cluster ID': 18.0, 'Link Score': 0.5454491376876831, 'unique_id': '1019', 'title': 'SONY IPOD/PHONE DOCK CLOCK RADIO BLACK NIC - ICFC1IPMK2BLK', 'price': '$80.25', 'source_file': 1, 'source file': 1}
# {}
# {}
# {}
# {}
# {'Cluster ID': 19.0, 'Link Score': 0.5454511642456055, 'unique_id': '1024', 'title': 'VholdR Wearable Camcorder (Black) - 1102', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 23.0, 'Link Score': 0.5454500317573547, 'unique_id': '1025', 'title': 'Sharp AQUOS BD-HP21U Blu-ray Disc Player', 'description': 'BD-RE, DVD+RW, DVD-RW, CD-RW - BD Video, DVD Video, JPEG, CD-DA, MPEG-2, VC-1, AC3, LPCM Playback - Progressive Scan', 'price': '$218.63', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 22.0, 'Link Score': 0.5454511642456055, 'unique_id': '1026', 'title': 'Sharp AQUOS BD-HP50U Blu-ray Disc Player', 'description': 'BD-RE, DVD+RW, DVD-RW, CD-RW - BD Video, DVD Video, CD-DA, JPEG, VC-1, MPEG-2, AC3, LPCM Playback - Progressive Scan', 'price': '$266.96', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 23.0, 'Link Score': 0.5454503297805786, 'unique_id': '1029', 'title': "Sharp AQUOS LC-42D85U 42' LCD TV", 'description': "42' - Active Matrix TFT - ATSC, NTSC - 16:9 - 1920 x 1080 - HDTV - 1080p", 'price': '$1,076.65', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 339.0, 'Link Score': 0.5454517602920532, 'unique_id': '1030', 'title': 'Escort Passport 9500ix Radar/Laser Detector', 'price': '$439.99', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 25.0, 'Link Score': 0.5454500317573547, 'unique_id': '1031', 'title': 'KITCHENAID KPFP850OB - Food Processor', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 26.0, 'Link Score': 0.5454440116882324, 'unique_id': '1032', 'title': 'Chestnut Hill CHS40001 Chestnut Hill George Ipod Dock Compact Stereo System', 'price': '$499.00', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 123.0, 'Link Score': 0.5454448461532593, 'unique_id': '1033', 'title': 'Escort 9500CI Escort GPS Radar Detector', 'price': '$1,475.99', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 28.0, 'Link Score': 0.5454503297805786, 'unique_id': '1034', 'title': 'Sony ICD-B600 512MB Digital Voice Recorder - ICDB600', 'description': '512MB Flash Memory - LCD - Portable', 'price': '$30.45', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 29.0, 'Link Score': 0.5454517602920532, 'unique_id': '1035', 'title': 'Canon PSC-4000 Deluxe Leather Case N - 3528B001', 'price': '$35.99', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 31.0, 'Link Score': 0.5454496741294861, 'unique_id': '1037', 'title': 'Sony BRAVIA VPL-HW10 Digital Projector - VPLHW10', 'description': '1920 x 1080 - 22.05lb', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 32.0, 'Link Score': 0.5454496145248413, 'unique_id': '1039', 'title': 'Altec Lansing IMT702 inMotion MAX Portable Speaker System for iPhone', 'price': '$133.96', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 33.0, 'Link Score': 0.5454500317573547, 'unique_id': '1042', 'title': 'Samsung BDP2500 - BD-P2500', 'price': '$301.05', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 34.0, 'Link Score': 0.5454511642456055, 'unique_id': '1043', 'title': 'Denon DVD-1800BD Blu-ray Disc Player', 'description': 'BD-R, DVD-R, CD-R, Secure Digital (SD) - BD Video, DVD Video, WMA, MP3, DivX 6, JPG Playback - Progressive Scan', 'price': '$499.00', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 35.0, 'Link Score': 0.545450747013092, 'unique_id': '1045', 'title': 'Canon Rebel XSi/XS Starter Kit - 9320A009', 'price': '$69.99', 'source_file': 1, 'source file': 1}
# {}
# {}
# {}
# {'Cluster ID': 37.0, 'Link Score': 0.5454495549201965, 'unique_id': '1049', 'title': 'Onkyo TX-8255 A/V Receiver', 'description': 'AM, FM', 'price': '$159.98', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 38.0, 'Link Score': 0.5454483032226562, 'unique_id': '1050', 'title': 'Denon DHT-589BA Home Theater System', 'description': ', A/V Receiver, 5.1 Speakers - Dolby Pro Logic II, DTS', 'price': '$448.80', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 39.0, 'Link Score': 0.5454511046409607, 'unique_id': '1051', 'title': "LG 42LG30 42' LCD TV", 'description': "LG 42LG30 42' LCD HDTV - 12,000:1 Dynamic Contrast Ratio - Invisible Speaker", 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 40.0, 'Link Score': 0.5454508662223816, 'unique_id': '1054', 'title': 'Apple iPod nano Armband - MB769G/A', 'description': 'Grey', 'price': '$29.00', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 41.0, 'Link Score': 0.5454530119895935, 'unique_id': '1056', 'title': 'Samsung SBH500 Stereo Bluetooth Headset', 'price': '$49.72', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 42.0, 'Link Score': 0.5454496145248413, 'unique_id': '1057', 'title': 'Sony DPFD100 Digital Photo Frame', 'description': "Photo Viewer - 10' LCD", 'price': '$249.12', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 143.0, 'Link Score': 0.5454476475715637, 'unique_id': '1059', 'title': 'Danby DDW497W Countertop Dishwasher', 'price': '$247.05', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 44.0, 'Link Score': 0.5454487800598145, 'unique_id': '1060', 'title': 'Sony XDR-S10HDiP Clock Radio with iPod Dock - XDRS10HDIP', 'description': 'LCD', 'price': '$149.95', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 46.0, 'Link Score': 0.5454472303390503, 'unique_id': '1061', 'title': 'Panasonic Kx-tg9391t Dect 6.0 Two-line Corded/cordless Phone Combo - KX-TG9391T', 'price': '$149.72', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 46.0, 'Link Score': 0.5454503297805786, 'unique_id': '1062', 'title': "Sony BRAVIA XBR Series KDL-46XBR6 46' LCD TV - KDL46XBR6", 'description': "46' - Active Matrix TFT - ATSC, NTSC - 16:9 - 1920 x 1080 - Dolby, Surround - HDTV - 480i, 480p, 720p, 1080i, 1080p", 'price': '$1,977.72', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 47.0, 'Link Score': 0.5454503297805786, 'unique_id': '1063', 'title': "Sony BRAVIA XBR Series KDL-52XBR6 52' LCD TV - KDL52XBR6", 'description': "52' - Active Matrix TFT - ATSC, NTSC - 16:9 - 1920 x 1080 - Dolby, Surround - HDTV - 480i, 480p, 720p, 1080i, 1080p", 'price': '$2,573.72', 'source_file': 1, 'source file': 1}
# {'Cluster ID': 48.0, 'Link Score': 0.5454497337341309, 'unique_id': '1064', 'title': 'Audiovox DPF701 7-Inch Acrylic Digital Picture Frame', 'price': '$41.40', 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 217.0, 'Link Score': 0.5454443693161011, 'unique_id': '1067', 'title': 'Simpletech 2GB SD Card - 3505B001AA', 'price': '$12.88', 'source_file': 1, 'source file': 1}
# {}
# {'Cluster ID': 485.0, 'Link Score': 0.5454481840133667, 'unique_id': '1092', 'title': "Samsung LN32A450 32' 720p LCD HDTV", 'source_file': 1, 'source file': 1}
# {}
# {}
# {'Cluster ID': 51.0, 'Link Score': 0.5454521775245667, 'unique_id': '1071', 'title': 'Canon XH A1S - 3238B001', 'price': '$3,999.00', 'source_file': 1, 'source file': 1}
# {}
# {}
# {}
# {}
# {'Cluster ID': 53.0, 'Link Score': 0.5454499125480652, 'unique_id': '1076', 'title': 'CASE MATE CARBON FIBER IPHONE 3G CASE BLACK - IPH3GC-BCF', 'price': '$28.08', 'source_file': 1, 'source file': 1}

# %%
print(json_cls)
# Out:
# [{'Cluster ID': 0.0, 'Link Score': 0.545451819896698, 'unique_id': '1', 'title': 'Linksys EtherFast 8-Port 10/100 Switch - EZXS88W', 'description': 'Linksys EtherFast 8-Port 10/100 Switch - EZXS88W/ 10/100 Dual-Speed Per-Port/ Perfect For Optimizing 10BaseT And 100BaseTX Hardware On The Same Network/ Speeds Of Up To 200Mbps In Full Duplex Operation/ Eliminate Bandwidth Constraints And Clear Up Bottlenecks', 'price': '$44.00', 'source_file': 0, 'source file': 0}, {'Cluster ID': 1.0, 'Link Score': 0.5454487800598145, 'unique_id': '2', 'title': 'Linksys EtherFast10/100 5-Port Auto-Sensing Switch - EZXS55W', 'description': 'Linksys EtherFast10/100 5-Port Auto-Sensing Switch - EZXS55W/ 5 Port 10/100 Autosensing Ports With Both Half And Full Duplex Modes/ Perfect For Integrating Your 10BaseT And 100BaseTX Network Hardware/ Switched 10/100 Ports Run At 10Mbps, 20Mbps, 100Mbps Up To 200Mbps', 'price': '$29.00', 'source_file': 0, 'source file': 0}, {'Cluster ID': 126.0, 'Link Score': 0.5454509854316711, 'unique_id': '3', 'title': 'Netgear ProSafe 5 Port 10/100 Desktop Switch - FS105', 'description': 'Netgear ProSafe 5 Port 10/100 Desktop Switch - FS105/ 5 Auto Speed-Sensing 10/100 UTP Ports/ Embedded Memory', 'price': '$40.00', 'source_file': 0, 'source file': 0}, {'Cluster ID': 200.0, 'Link Score': 0.5454516410827637, 'unique_id': '4', 'title': 'Belkin F3H982-10 Pro Series High Integrity 10 Feet Monitor Cable - F3H98210', 'description': "Belkin F3H982-10 Pro Series High Integrity 10 Feet Monitor Cable - F3H98210/ Recommended For Monitors 17' And Larger/ Designed To Support High Resolution Imaging And High Speed/ Double Shielding/ Gold Plated Copper Contacts", 'source_file': 0, 'source file': 0}, {'source_file': 0, 'unique_id': '5', 'title': 'Netgear Prosafe 16 Port 10/100 Rackmount Switch - Black Finish - JFS516NA', 'description': 'Netgear Prosafe 16 Port 10/100 Rackmount Switch - JFS516NA/ Sixteen Switched Ports Provide Private Bandwidth For PCs, Servers Or Hubs/ Store-And-Forward Packet Switching/ Compatible With All Major Network Software/ Auto Detects Speed And Duplex/ Black Finish', 'price': '$131.00', 'source file': 0}, {'Cluster ID': 356.0, 'Link Score': 0.5454540252685547, 'unique_id': '6', 'title': 'LaCie USB 2.0 Floppy Disk Drive - 706018', 'description': 'LaCie USB 2.0 Floppy Disk Drive - 706018/ Ultra-Thin Portable Design/ Compatible With Windows And Mac OS/ Plug And Play/ USB Powered/ 250 - 500 kbps Transfer Rate/ Silver Finish', 'price': '$49.00', 'source_file': 0, 'source file': 0}, {'source_file': 0, 'unique_id': '7', 'title': 'Canon KP-36IP Color Ink & Paper Set - 7737A001', 'description': "Canon KP-36IP Color Ink & Paper Set - 7737A001/ 36 Sheets Of 4' x 6' Photo Paper/ Ink Cartridge For Compatible Canon Dye Sublimation Printer", 'price': '$12.00', 'source file': 0}, {'Cluster ID': 504.0, 'Link Score': 0.5454544425010681, 'unique_id': '8', 'title': 'Kensington Orbit Optical Trackball Mouse - 64327', 'description': 'Kensington Orbit Optical Trackball Mouse - 64327/ DiamondEye Optical Technology For Precise Tracking And Cursor Control/ USB And PS/2 Connectivity For Greater Compatibility/ Windows And Mac Compatible/ Metallic Silver And Black Finish', 'price': '$38.00', 'source_file': 0, 'source file': 0}, {'Cluster ID': 573.0, 'Link Score': 0.545451819896698, 'unique_id': '9', 'title': 'Linksys EtherFast4116 16-Port 10/100 Ethernet Switch - EF4116', 'description': 'Linksys EtherFast4116 16-Port 10/100 Ethernet Switch - EF4116/ 16 Autosensing 10/100 Full Duplex Auto MDI/MDI-X Ports/ Run Blazing Speeds Up To 200Mbps/ Address Learning And Aging And Data Flow Control', 'price': '$79.00', 'source_file': 0, 'source file': 0}, {'Cluster ID': 651.0, 'Link Score': 0.5454521775245667, 'unique_id': '10', 'title': 'Linksys EtherFast 4124 24-Port Ethernet Switch - EF4124', 'description': 'Linksys EtherFast 4124 24-Port Ethernet Switch - EF4124/ 24 Autosensing 10/100 Full Duplex, Auto MDI/MDI-X Ports/ Up To 200Mbps/ Address Learning, ...

# %%
df1=spark.createDataFrame(json_cls)

# %%
df1.coalesce(1).write.format("csv").option("header","true").mode("overwrite").save("Untitled Folder/")

# %%
df1.count()
# Out:
# 2173
